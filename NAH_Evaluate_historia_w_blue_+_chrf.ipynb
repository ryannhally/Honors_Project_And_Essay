# %% [markdown]
# <a href="https://colab.research.google.com/github/ryannhally/Honors_Project_And_Essay/blob/main/NAH_Evaluate_historia_w_blue_%2B_chrf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install libraries
# !pip install transformers datasets evaluate sacrebleu morfessor
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ...

# %%
# Import metrics
from evaluate import load

chrf_metric = load('chrf')
bleu_metric = load('sacrebleu')
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
import sacrebleu

# %%
import re

file = 'refs_and_candids_historia.txt'
count = 1
candidates = []

all_references = []
all_candidates = []

with open(file, 'r') as file:
  lines = file.readlines()

  # in groups of 5
  for i in range(0, len(lines), 5):
    # saves first line as reference
    reference = lines[i].strip().lower()  # First line is reference
    #all_references.append(reference)
    # save lines 2-4 as candidates
    for j in range(i + 1, i + 5):
      candidate = lines[j].strip().lower()

      bleu_score = sacrebleu.sentence_bleu(candidate, [reference])
      print("Reference:", reference)
      print("Candidate:", candidate)
      print("BLEU:", bleu_score.score)

      all_references.append([reference])
      all_candidates.append(candidate)


#bleu_total = bleu_metric.compute(predictions=all_candidates, references=all_references)
#print(type(bleu))

'''

for candidate, reference in zip(all_candidates, all_references):
  bleu = bleu_metric.compute(predictions=predictions, references=references)
  print('Reference: ', reference,'Candidate: ', candidate,'sacreBLEU: ', bleu['score'])


    #print("REFERENCE: ", reference)
    for k, candidate in enumerate(candidates):
        print(f"     translation {k + 1}: ", candidate)

        #score = evaluate(reference, candidate)

        print("     score:", score)
'''
# Out:
# Reference: ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# Candidate: ipan 12 pedernal nopa mexikamej yajkej tecpayocan
# BLEU: 6.770186228657864
# Reference: ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# Candidate: ipan matlaktlomome tekpatl xiuitl oyake mexikaj tekpayokan
# BLEU: 5.693025330278465
# Reference: ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# Candidate: ipan matlaktlomei tekpatl xiuitl
# BLEU: 5.876350803261633
# Reference: ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# Candidate: ipan matlaktli ompa tekpayokan oy
# BLEU: 5.862502026550896
# Reference: inin xiuhpan ompehua in motocayotia cristerosme inyaoyo
# Candidate: ni xiuitl peua nopa tlen itoka guerra de cristero
# BLEU: 0.0
# Reference: inin xiuhpan ompehua in motocayotia cristerosme inyaoyo
# Candidate: inin xiupan ompeua in motokayotia kristerosyayaoyotl
# BLEU: 8.170609724417774
# ...

# %%
import re

file = 'refs_and_candids_historia.txt'
count = 1

references = []
candidates = []

with open(file, 'r') as file:
  lines = file.readlines()

  # in groups of 5
  for i in range(0, len(lines), 5):
    # saves first line as reference
    reference = lines[i].strip().lower()  # First line is reference
    # save lines 2-4 as candidates
    for j in range(i + 1, i + 5):
      candidates += [lines[j].strip().lower()]
      #print("NEW CANDIDATE: ", [lines[j].strip().lower()])
      references += [reference]
      #print("REFERENCE: ", references)
      #print("CANDIDATE LIST: ", candidates)

    #bleu_score = sacrebleu.sentence_bleu(candidate, [reference])


#chrf = chrf_metric.compute(predictions=candidates, references=references)


print(len(candidates))
print(len(references))


for i in range (0, 20):
  print(candidates[i])
  print(references[i])
  print(i)
  chrf = chrf_metric.compute(predictions=[candidates[i]], references=[references[i]])

  print('Reference: ', references[i],'Candidate: ', candidates[i],'CHRF: ', chrf['score'])
# Out:
# 20
# 20
# ipan 12 pedernal nopa mexikamej yajkej tecpayocan
# ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# 0
# Reference:  ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan Candidate:  ipan 12 pedernal nopa mexikamej yajkej tecpayocan CHRF:  26.105007326254448
# ipan matlaktlomome tekpatl xiuitl oyake mexikaj tekpayokan
# ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# 1
# Reference:  ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan Candidate:  ipan matlaktlomome tekpatl xiuitl oyake mexikaj tekpayokan CHRF:  47.1315042415601
# ipan matlaktlomei tekpatl xiuitl
# ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# 2
# Reference:  ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan Candidate:  ipan matlaktlomei tekpatl xiuitl CHRF:  29.409461682651113
# ipan matlaktli ompa tekpayokan oy
# ipan matlactli omome tecpatl xihuitl oyaque mexicah tecpayocan
# 3
# ...
